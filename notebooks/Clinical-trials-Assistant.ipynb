# %% [markdown]
# # 🧪 Clinical Trial Assistant – Jupyter Notebook Demo
#
# This notebook walks through the full pipeline of the **Clinical Trial Assistant** project:
#
# • Loading the knowledge base
# • Embedding content
# • Retrieving relevant information
# • Generating safe, clinical-style responses with Groq
#
# ---
#
# ## 1️⃣ Setup

# %%
# Install dependencies (Colab / local)
# !pip install -q sentence-transformers groq python-dotenv pandas

# Silence logs
import os, warnings
os.environ["TRANSFORMERS_VERBOSITY"] = "error"
os.environ["TOKENIZERS_PARALLELISM"] = "false"
warnings.filterwarnings("ignore")

# Load Groq API key (Colab)
from google.colab import userdata
import os
os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")
print("API key loaded:", bool(os.environ.get("GROQ_API_KEY")))

# Setup path
import sys

PROJECT_ROOT = "/content/clinical-trial-assistant"

# Add project root to Python path
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# Make sure folders are packages
open(os.path.join(PROJECT_ROOT, "__init__.py"), "w").close()
open(os.path.join(PROJECT_ROOT, "src", "__init__.py"), "w").close()

print("✅ Project path configured")
# Out:
# API key loaded: True
# ✅ Project path configured

# %% [markdown]
# # 2️⃣ Project Imports

# %%
import sys

from src.main import run

# %% [markdown]
# # 3️⃣ Ask the Assistant

# %%
print(run("Can I take ibuprofen during the study?"))
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# I understand you're asking about taking ibuprofen during the study. Unfortunately, according to the study rules, we are not allowed to take ibuprofen, along with other nonsteroidal anti-inflammatory drugs (NSAIDs), such as aspirin and naproxen.
#
# However, if you're experiencing pain, you can take acetaminophen, but please make sure to follow the recommended dosage and only take it as directed by the study team. If you have any questions or concerns about pain management, I encourage you to reach out to our study team for guidance. They will be happy to help you find a safe and effective solution.

# %% [markdown]
# # 4️⃣ Example Output
# The assistant will: • Follow clinical trial rules • Give safe guidance • Escalate emergencies
#
# # 5️⃣ What This Demonstrates
# ✔ Retrieval-Augmented Generation (RAG) ✔ Safety logic for medical contexts ✔ LLM integration with Groq ✔ Portfolio-ready project structure
